# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
var = pd.read_csv('/content/car.csv')

# %%
print(var.dtypes)
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
print(var.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
print(var.isnull().sum())
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
print(var.describe().transpose())
# Out:
#                count          mean           std  ...      50%      75%       max
# Year           301.0   2013.627907      2.891554  ...   2014.0   2016.0    2018.0
# Selling_Price  301.0      4.661296      5.082812  ...      3.6      6.0      35.0
# Present_Price  301.0      7.628472      8.644115  ...      6.4      9.9      92.6
# Kms_Driven     301.0  36947.205980  38886.883882  ...  32000.0  48767.0  500000.0
# Owner          301.0      0.043189      0.247915  ...      0.0      0.0       3.0
#
# [5 rows x 8 columns]

# %%
print(var.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB
# None

# %%
print(var.shape)
# Out:
# (301, 9)

# %%
print(var.dtypes[var.dtypes==object])
# Out:
# Car_Name        object
# Fuel_Type       object
# Seller_Type     object
# Transmission    object
# dtype: object

# %%
var.head(2)
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
#
# [2 rows x 9 columns]

# %%
a=var[[ 'Car_Name','Fuel_Type','Seller_Type','Transmission']]
for col in a:
    print(var[col].value_counts())
    print('---------------------------------------------------------')
# Out:
# city                      26
# corolla altis             16
# verna                     14
# fortuner                  11
# brio                      10
#                           ..
# land cruiser               1
# Honda Dream Yuga           1
# Honda CB Unicorn           1
# Bajaj Discover 100         1
# Hero Honda Passion Pro     1
# Name: Car_Name, Length: 98, dtype: int64
# ---------------------------------------------------------
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64
# ---------------------------------------------------------
# Dealer        195
# Individual    106
# Name: Seller_Type, dtype: int64
# ---------------------------------------------------------
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64
# ---------------------------------------------------------

# %%
print(var.Fuel_Type.value_counts().plot(kind="bar",color='violet'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(var.Transmission.value_counts().plot(kind="bar",color='yellow'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(var.Seller_Type.value_counts().plot(kind="bar",color='green'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
var.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
var['present_year']=2021
print(var.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner', 'present_year'],
#       dtype='object')

# %%
var['total_years'] = var['present_year']-var['Year']
print(var.columns)
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner', 'present_year',
#        'total_years'],
#       dtype='object')

# %%
var.head(2)
# Out:
#   Car_Name  Year  Selling_Price  ...  Owner  present_year total_years
# 0     ritz  2014           3.35  ...      0          2021           7
# 1      sx4  2013           4.75  ...      0          2021           8
#
# [2 rows x 11 columns]

# %%
var.drop(['Year','present_year'],axis=1,inplace=True)

# %%
print(var.columns)
# Out:
# Index(['Car_Name', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'total_years'],
#       dtype='object')

# %%
print(var.head(2))
# Out:
#   Car_Name  Selling_Price  Present_Price  ...  Transmission Owner total_years
# 0     ritz           3.35           5.59  ...        Manual     0           7
# 1      sx4           4.75           9.54  ...        Manual     0           8
#
# [2 rows x 9 columns]

# %%
var.drop(['Car_Name'],axis=1,inplace=True)

# %%
var.head(4)
# Out:
#    Selling_Price  Present_Price  Kms_Driven  ... Transmission Owner total_years
# 0           3.35           5.59       27000  ...       Manual     0           7
# 1           4.75           9.54       43000  ...       Manual     0           8
# 2           7.25           9.85        6900  ...       Manual     0           4
# 3           2.85           4.15        5200  ...       Manual     0          10
#
# [4 rows x 8 columns]

# %%
print(var.Fuel_Type.value_counts())
print('-----------------------')
print(var.Seller_Type.value_counts())
print('-----------------------')
print(var.Transmission.value_counts())
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64
# -----------------------
# Dealer        195
# Individual    106
# Name: Seller_Type, dtype: int64
# -----------------------
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
dummie1 ={'Petrol':0,'Diesel':1,'CNG':2}
var['Fuel_Type'] = var['Fuel_Type'].map(dummie1)

dummie2 ={'Dealer':0,'Individual':1}
var['Seller_Type'] = var['Seller_Type'].map(dummie2)

dummie3 ={'Manual':0,'Automatic':1}
var['Transmission'] = var['Transmission'].map(dummie3)

# %%
var.isnull().sum()
# Out:
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# total_years      0
# dtype: int64

# %%
sns.pairplot(var)

# %%
print(var.corr())
# Out:
#                Selling_Price  Present_Price  ...     Owner  total_years
# Selling_Price       1.000000       0.878983  ... -0.088344    -0.236141
# Present_Price       0.878983       1.000000  ...  0.008057     0.047584
# Kms_Driven          0.029187       0.203647  ...  0.089216     0.524342
# Fuel_Type           0.509467       0.440415  ... -0.055705    -0.053643
# Seller_Type        -0.550724      -0.512030  ...  0.124269     0.039896
# Transmission        0.367128       0.348715  ...  0.050316     0.000394
# Owner              -0.088344       0.008057  ...  1.000000     0.182104
# total_years        -0.236141       0.047584  ...  0.182104     1.000000
#
# [8 rows x 8 columns]

# %%
sns.heatmap(var.corr(),annot = True,cmap='rainbow')

# %%
print(var.columns,end='')
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'total_years'],
#       dtype='object')

# %%
y=var['Selling_Price']
x=var[[ 'Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner', 'total_years']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.feature_selection import mutual_info_regression
from hyperopt import hp,fmin,tpe,STATUS_OK,Trials
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
etr=ExtraTreesRegressor(random_state=101)
etr.fit(x,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=101, verbose=0, warm_start=False)

# %%
pd.Series(etr.feature_importances_, index = x.columns).nlargest(4).plot(kind = 'bar')

# %%
rfr = RandomForestRegressor()
rfr.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=0)

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
min_samples_split = [2, 5, 10, 15, 100]
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
forest = RandomizedSearchCV(estimator = rfr, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
print(forest)
# Out:
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
# ...

# %%
forest.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.2s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.2s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   1.2s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# ...

# %%
y_pred = forest.predict(x_test)
print(y_pred)
# Out:
# [ 7.15639   0.53128   4.99      8.7934   15.65794   5.00218   3.3824
#   0.74463   4.79035   4.4972    3.11596   0.86835   4.96408   8.02185
#   7.80946  11.33569   7.41794   4.16815   0.48022   1.48795   4.29079
#   4.69368   5.68292   9.722935  0.24817   0.76552   0.59274   0.64384
#   0.47719   5.01917   4.55725   5.875     0.49425   8.49846   3.55652
#   1.17451   5.69898   6.74926   0.23632   8.94556   8.80769  19.4249
#   4.91515   4.16913   5.48145  11.288795  0.3183    0.89796   5.08155
#   7.56956   7.59788   3.54338   4.87065  20.88835   1.10069   1.04282
#   0.49891   2.75315   3.6116    1.29112   4.06932   8.58084   3.17441
#  20.55942   4.2194    5.78101  10.451985  5.10541   0.55312   3.0091
#   3.44997   3.0279    0.62189   5.50015   1.16859   2.77213   0.50632
#   9.302005  1.34177   2.83035   0.49314  10.65827   6.42695   5.75402
#   5.31017   0.94396   5.58569   6.02625   0.45655   4.98513   0.62178 ]

# %%
 plt.scatter(y_test, y_pred)
 plt.xlabel('True Values ')
 plt.ylabel('Predictions ')
# Out:
# Text(0, 0.5, 'Predictions ')

# %%
sns.histplot(y_test-y_pred,kde = True)

# %%
print('MAE is:',mean_absolute_error(y_test,y_pred))
print('MSE is:',mean_squared_error(y_test,y_pred))
print('RMSE is:',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# MAE is: 0.8614927472527418
# MSE is: 3.7362598062670296
# RMSE is: 1.9329407146281103
